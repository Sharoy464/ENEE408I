# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from google.colab import drive


drive.mount('/content/Mydrive')

img = cv.imread('/content/Mydrive/MyDrive/brown-tabby-licking-paw-in-dark-room-sw-769693.jpg', cv.IMREAD_GRAYSCALE)

assert img is not None, "file could not be read, check with os.path.exists()"

edges = cv.Canny(img,100,200)

plt.figure(figsize=(12, 6))

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# Drive already mounted at /content/Mydrive; to attempt to forcibly remount, call drive.mount("/content/Mydrive", force_remount=True).

# %%
import cv2 as cv
from matplotlib import pyplot as plt

# Read image (color by default)
img = cv.imread('/content/Mydrive/MyDrive/brown-tabby-licking-paw-in-dark-room-sw-769693.jpg')

# Convert to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# Display
plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

face_cascade = cv.CascadeClassifier(cv.data.haarcascades + "haarcascade_frontalface_default.xml")

img = cv.imread("/content/Mydrive/MyDrive/human face.png")
assert img is not None, "Image not found. Check the path."


gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)


faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)

print("Faces found:", len(faces))


for (x, y, w, h) in faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)


plt.figure(figsize=(8,6))
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# Faces found: 1
